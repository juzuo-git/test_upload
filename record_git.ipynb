# %%
_str = """
 1012  git init
 1013  git status -s
 1014  git add .
 1015  git status -s
 1016  git commit -m "first_submit"
 1017  git config --global juzuo.lee@qq.com
 1019  git config --global user.name "Juzuo"
 1020  git config --global user.email "juzuo.lee@qq.com"
 1021  git commit -m "first_submit"
 1022  git remote add origin git@github.com:juzuo-git/test_upload.git
 1023  git push -u origin master
 1024  ssh-keygen -t rsa -C "juzuo.lee@qq.com"
 1028  less /public/home/lijz/.ssh/id_rsa_github
 1029  cat /public/home/lijz/.ssh/id_rsa_github
 1030  cat /public/home/lijz/.ssh/id_rsa_github.pub 
 1031  git remote add origin git@github.com:juzuo-git/test_upload.git
 1033  git branch -M main
 1034  git remote add origin git@github.com:juzuo-git/test_upload.git
 1035  git push -u origin main
 1048  ls -al ~/.ssh
 1049  eval `ssh-agent -s`
 1050  ssh-add ~/.ssh/id_rsa_github
 1051  ssh -T git@github.com
 1068  git push -u origin main
"""

# %%
for line in _str.split("\n"):
    _tl = line.split("  ")
    print(_tl[-1])
# Out:
# git init
# git status -s
# git add .
# git status -s
# git commit -m "first_submit"
# git config --global juzuo.lee@qq.com
# git config --global user.name "Juzuo"
# git config --global user.email "juzuo.lee@qq.com"
# git commit -m "first_submit"
# git remote add origin git@github.com:juzuo-git/test_upload.git
# git push -u origin master
# ssh-keygen -t rsa -C "juzuo.lee@qq.com"
# less /public/home/lijz/.ssh/id_rsa_github
# cat /public/home/lijz/.ssh/id_rsa_github
# cat /public/home/lijz/.ssh/id_rsa_github.pub
# git remote add origin git@github.com:juzuo-git/test_upload.git
# git branch -M main
# git remote add origin git@github.com:juzuo-git/test_upload.git
# git push -u origin main
# ls -al ~/.ssh
# eval `ssh-agent -s`
# ssh-add ~/.ssh/id_rsa_github
# ssh -T git@github.com
# git push -u origin main

# %%
# %pwd
# Out:
# '/data/Zhaijx/lijz/Some_task/git_upload/0_up_test'

# %% [markdown]
# #### 进入测试文件夹
#
# ```
# git init
# git status -s
# ```
#
# ![image.png](attachment:image.png)
#
# ```
# git add .
# git status -s
# ```
# ![image-2.png](attachment:image-2.png)
#
#
# ```
# git commit -m "first_submit"
# ```
#
# #### 报出错误1
#
# ![image-3.png](attachment:image-3.png)
#
# #### 按照他的要求添加相关的信息：
# ```
# git config --global juzuo.lee@qq.com
# git config --global user.name "Juzuo"
# git config --global user.email "juzuo.lee@qq.com"
# git commit -m "first_submit"
# ```
#
# ![image-4.png](attachment:image-4.png)
# - 成功建立本地的提交
#
# ```
# git remote add origin git@github.com:juzuo-git/test_upload.git
# git push -u origin master
# ```
# #### 报出错误2
#
# ![image-6.png](attachment:image-6.png)
#
# ```
# ssh-keygen -t rsa -C "juzuo.lee@qq.com"
# ```
#
# ![image-5.png](attachment:image-5.png)
# - 注意截图中：我为了避免覆盖原始的id_rsa，所以创建了新的密钥 id_rsa_github
#
#
# #### 然后复制公钥中的信息，粘贴到 new SHH key 中
#
# ![image-7.png](attachment:image-7.png)
# ```
# less /public/home/lijz/.ssh/id_rsa_github
# cat /public/home/lijz/.ssh/id_rsa_github.pub
# ```
#
# #### 然后按照下面以此运行
# ```
# git remote add origin git@github.com:juzuo-git/test_upload.git
# git branch -M main
# git remote add origin git@github.com:juzuo-git/test_upload.git
# git push -u origin main
# ls -al ~/.ssh
# eval `ssh-agent -s`
# ssh-add ~/.ssh/id_rsa_github
# ssh -T git@github.com
# ```
#
# - 得到下面的信息：
#
# ![image-8.png](attachment:image-8.png)
#
# #### 然后即可上传：
# ```
# git push -u origin main
# ```
#
# ![image-9.png](attachment:image-9.png)
#
# #### 成功！
